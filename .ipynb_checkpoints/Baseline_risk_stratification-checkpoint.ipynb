# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import-data" data-toc-modified-id="Import-data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Import data</a></span></li><li><span><a href="#create-'readmit_30'-label-in-baseline-data" data-toc-modified-id="create-'readmit_30'-label-in-baseline-data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>create 'readmit_30' label in baseline data</a></span></li><li><span><a href="#Extract-only-attributes-in-the-'Static-Characteristic'-dict" data-toc-modified-id="Extract-only-attributes-in-the-'Static-Characteristic'-dict-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Extract only attributes in the 'Static Characteristic' dict</a></span></li><li><span><a href="#Normalize-numeric-attributes" data-toc-modified-id="Normalize-numeric-attributes-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Normalize numeric attributes</a></span></li><li><span><a href="#One-hot-representation-for-categorical-attributes" data-toc-modified-id="One-hot-representation-for-categorical-attributes-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>One-hot representation for categorical attributes</a></span><ul class="toc-item"><li><span><a href="#RACE" data-toc-modified-id="RACE-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>RACE</a></span></li><li><span><a href="#TOBACCO-STATUS" data-toc-modified-id="TOBACCO-STATUS-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>TOBACCO STATUS</a></span></li><li><span><a href="#Insurance-Payer" data-toc-modified-id="Insurance-Payer-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Insurance Payer</a></span></li></ul></li><li><span><a href="#Save-the-cleaned-and-processed-dataset" data-toc-modified-id="Save-the-cleaned-and-processed-dataset-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Save the cleaned and processed dataset</a></span></li><li><span><a href="#Office-visit-attributes" data-toc-modified-id="Office-visit-attributes-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Office visit attributes</a></span><ul class="toc-item"><li><span><a href="#Mean-imputation-on-office-measurements-except-BMI" data-toc-modified-id="Mean-imputation-on-office-measurements-except-BMI-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Mean imputation on office measurements except BMI</a></span></li><li><span><a href="#Mean-Imputation-on-BMI" data-toc-modified-id="Mean-Imputation-on-BMI-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Mean Imputation on BMI</a></span></li><li><span><a href="#Normalize-numeric-attributes" data-toc-modified-id="Normalize-numeric-attributes-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Normalize numeric attributes</a></span></li></ul></li><li><span><a href="#Split-to-training-and-validation-set" data-toc-modified-id="Split-to-training-and-validation-set-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Split to training and validation set</a></span></li><li><span><a href="#Logistic-Regression" data-toc-modified-id="Logistic-Regression-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Logistic Regression</a></span></li><li><span><a href="#Random-Forest" data-toc-modified-id="Random-Forest-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Random Forest</a></span></li><li><span><a href="#Examine-the-Office-Visit-Measurements" data-toc-modified-id="Examine-the-Office-Visit-Measurements-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Examine the Office Visit Measurements</a></span></li><li><span><a href="#Examine-the-initial-admission-measurements" data-toc-modified-id="Examine-the-initial-admission-measurements-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Examine the initial admission measurements</a></span></li><li><span><a href="#Examine-the-HIS" data-toc-modified-id="Examine-the-HIS-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>Examine the HIS</a></span></li></ul></div>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

pd.options.display.max_rows = 400
pd.options.display.max_columns = 50

# %% [markdown]
# # Import data

# %%
# %cd ~/desktop/datasets/processed
# Out:
# /Users/jinchenxie/Desktop/datasets/processed

# %%
baseline = pd.read_excel('Filtered Attributes Baseline.xlsx', 
                          'updated_folup_NA30_baseline')

# %%
admission = pd.read_excel('Filtered Attributes Admission.xlsx', 
                          'NA2030_filtered_admission')

# %%
# %cd ~/desktop/HF_Research/datasets
# Out:
# /Users/jinchenxie/Desktop/HF_Research/datasets

# %%
baseline_old = pd.read_excel('Advanced Therapy Potential Cohort.xlsx', 
                          'cohort baseline')

# %%
admission_old = pd.read_excel('Advanced Therapy Potential Cohort.xlsx', 
                          'admission (upto 15th)')

# %% [markdown]
# # create 'readmit_30' label in baseline data
# This label only considers the 30-day readmission after the index admission.

# %%
admission_1 = admission_old[admission_old['INDEX_HOSPITALIZATION']==1]

# %%
readmit_30_label = admission_1.readmit_30_label
readmit_30_label.reset_index(drop=True, inplace=True)

# %%
baseline['readmit_30'] = readmit_30_label

# %% [markdown]
# # Extract only attributes in the 'Static Characteristic' dict

# %%
attris_1 = ['AGE_ADMISSION','FEMALE','RACE',
            'TOBACCO_STATUS_LABEL','HOSP_ROLLUP_GROUPING2']

attris_his = ['HTN_HST','HYPERLIPIDEMIA_HST','DIAB_HST','COPD_HST','CAD_HST',
'CHF_HST','AFIB_HST','PH_HST','PE_HST','CARDIAC_ARREST_HST','VTVF_HST',
'VASCULARDISEASE_HST','DVT_HST','STROKE_HST','HEMO_STROKE_HST',
'MAJOR_BLEED_HST','CKD_HST','ESRD_HST','CIRRHOSIS_HST','HX_SEPTIC_SHOCK',
'HX_SEPSIS','HX_CAROTID_OCCLUSION','RESTRICTIVE_CARDIOMYOPATHY',
'HYPERTROPHIC_CARDIOMYOPATHY','ISCHEMIC_CARDIOMYOPATHY','PERIPARTUM_CARDIOMYOPATHY',
'VIRAL_CARDIOMYOPATHY','DILATED_CARDIOMYOPATHY','ALCOHOLIC_CARDIOMYOPATHY']

attris_cci = ['CCI_MI','CCI_CHF','CCI_PERIPHERAL_VASC','CCI_CEREBROVASCULAR',
              'CCI_DEMENTIA','CCI_COPD','CCI_RHEUMATIC_DISEASE',
              'CCI_PEPTIC_ULCER','CCI_MILD_LIVER_DISEASE','CCI_DM_NO_CC',
              'CCI_DM_WITH_CC','CCI_HEMIPLEGIA','CCI_RENAL_DISEASE',
              'CCI_AIDS_HIV','CCI_TOTAL_SCORE']

attris_pre = ['PRE_CRT','PRIOR_STERNOTOMY','PRIOR_PCI','PRIOR_CABG',
              'PRIOR_TAVR','PRIOR_SAVR_MECH','PRIOR_SAVR_BIO',
              'PRIOR_SURG_AO_GRFT','PRIOR_ENDO_AO_GRFT','PRIOR_AO_VLV_REPAIR',
              'PRIOR_SMVR','PRIOR_SPVR','PRIOR_STVR']

label = ['readmit_30']

# %%
attris_all = ['rID']
[attris_all.append(i) for i in attris_1]
[attris_all.append(i) for i in attris_his]
[attris_all.append(i) for i in attris_cci]
[attris_all.append(i) for i in label]
# Out:
# [None]

# %%
data_raw = baseline[attris_all]
static_data = baseline[attris_all]

# %%
static_data.describe()
# Out:
#                 rID  AGE_ADMISSION       FEMALE      HTN_HST  \
# count   2521.000000    2521.000000  2521.000000  2521.000000
# mean    6256.639825      60.913923     0.353828     0.550972
# std     3527.603018      10.898928     0.478251     0.497494
# min        5.000000      19.000000     0.000000     0.000000
# 25%     3200.000000      55.000000     0.000000     0.000000
# 50%     6391.000000      63.000000     0.000000     1.000000
# 75%     9282.000000      69.000000     1.000000     1.000000
# max    12280.000000      75.000000     1.000000     1.000000
#
#        HYPERLIPIDEMIA_HST     DIAB_HST     COPD_HST      CAD_HST      CHF_HST  \
# count         2521.000000  2521.000000  2521.000000  2521.000000  2521.000000
# mean             0.421658     0.391908     0.182071     0.447838     0.669972
# std              0.493922     0.488273     0.385979     0.497370     0.470316
# min              0.000000     0.000000     0.000000     0.000000     0.000000
# ...

# %% [markdown]
# # Normalize numeric attributes

# %% [markdown]
# Normalization:
# (x - min(x)) / (max(x) - min(x))
# data_norm

# %%
attris_numeric = ['AGE_ADMISSION','CCI_TOTAL_SCORE']

# %%
data_norm = data_raw.copy()
for attri in attris_numeric:
    data_norm[attri] = ((data_raw[attri]-data_raw[attri].min())/
                       (data_raw[attri].max()-data_raw[attri].min()))

# %% [markdown]
# # One-hot representation for categorical attributes

# %%
attris_cat = ['RACE', 'TOBACCO_STATUS_LABEL','HOSP_ROLLUP_GROUPING2']

# %%
data_norm[attris_cat]
# Out:
#        RACE          TOBACCO_STATUS_LABEL HOSP_ROLLUP_GROUPING2
# 0     Black                       CURRENT            Commercial
# 1     White                         NEVER              Medicare
# 2     White                         NEVER              Medicare
# 3     White      QUIT (UNKNOWN TIMEFRAME)              Medicare
# 4     White                       CURRENT              Medicare
# ...     ...                           ...                   ...
# 2516  Black  REMOTE (MORE THAN 12 MONTHS)            Commercial
# 2517  White                       CURRENT              Medicaid
# 2518  White                         NEVER              Medicaid
# 2519  White      QUIT (UNKNOWN TIMEFRAME)              Medicare
# 2520  White                       CURRENT              Medicare
#
# [2521 rows x 3 columns]

# %% [markdown]
# ## RACE

# %% [markdown]
# alter RACE to binary with 'White' 1 and 'Others' 0.

# %%
data_processed = data_norm.copy()

# %%
data_processed = pd.get_dummies(data=data_processed, columns=['RACE'])

data_processed.drop(columns=['RACE_America','RACE_Chinese','RACE_Decline','RACE_Indian',
                            'RACE_Not Spe', 'RACE_Other A','RACE_Vietnam','RACE_Black'],inplace=True)

# %% [markdown]
# ## TOBACCO STATUS

# %%
data_processed['TOBACCO_STATUS_LABEL'].value_counts()
# Out:
# QUIT (UNKNOWN TIMEFRAME)        951
# NEVER                           732
# CURRENT                         434
# RECENT (WITHIN 12 MONTHS)       148
# REMOTE (MORE THAN 12 MONTHS)    129
# UNKNOWN                          97
# NEVER ASKED                      21
# PASSIVE                           9
# Name: TOBACCO_STATUS_LABEL, dtype: int64

# %% [markdown]
# 3 LEVEL OF SMOKING STATUS
# - QUIT/REMOTE
# - NEVER
# - CURRENT/RECENT

# %%
temp_series = data_processed['TOBACCO_STATUS_LABEL']

for i in range(len(temp_series)):
    if (temp_series[i]=='QUIT (UNKNOWN TIMEFRAME)' or 
       temp_series[i]=='REMOTE (MORE THAN 12 MONTHS)'):
        temp_series[i] = 'Q/Remote'
    elif (temp_series[i]=='CURRENT' or 
       temp_series[i]=='RECENT (WITHIN 12 MONTHS)'):
        temp_series[i] = 'C/Recent'
    elif (temp_series[i]=='NEVER'):
        temp_series[i] = 'Never'
    else:
        temp_series[i] = 'NA'
# Out:
# /Users/jinchenxie/miniconda3/envs/research_env/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /Users/jinchenxie/miniconda3/envs/research_env/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/jinchenxie/miniconda3/envs/research_env/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
data_processed['TOBACCO_STATUS_LABEL'] = temp_series

# %%
temp_series.value_counts()
# Out:
# Q/Remote    1080
# Never        732
# C/Recent     582
# NA           127
# Name: TOBACCO_STATUS_LABEL, dtype: int64

# %%
data_processed = pd.get_dummies(data=data_processed,
                               columns=['TOBACCO_STATUS_LABEL'],
                               prefix=['TOBACCO']
                               )
data_processed.drop('TOBACCO_NA',1,inplace=True)

# %% [markdown]
# ## Insurance Payer

# %%
data_processed['HOSP_ROLLUP_GROUPING2'].value_counts()
# Out:
# Medicare        1457
# Commercial       617
# Medicaid         377
# Self Pay/ Ot      70
# Name: HOSP_ROLLUP_GROUPING2, dtype: int64

# %%
data_processed = pd.get_dummies(data=data_processed,
                               columns=['HOSP_ROLLUP_GROUPING2'],
                               prefix=['INSUR']
                               )

# %% [markdown]
# # Save the cleaned and processed dataset

# %%
# %pwd
# %cd processed
# Out:
# /Users/jinchenxie/Desktop/HF_Research/datasets/processed

# %%
writer = pd.ExcelWriter('Static Characteristics.xlsx')
data_processed.to_excel(writer, 'static')
writer.save()
print('DataFrame is written successfully to Excel File.')
# Out:
# DataFrame is written successfully to Excel File.

# %% [markdown]
# # Office visit attributes

# %%
'DAYS_TO_CLOSEST_OFFICE_VISIT', 'DEPARTMENT_SPECIALTY'

# %%
attris_office = [ 'BP_SYSTOLIC',
       'BP_DIASTOLIC', 'PULSE', 'BMI','WBC',  'HGB',
       'CR', 'EGFR', 'K',  'NA',
        'GLUCOSE','ALBUMIN',
       'PLATELETS',  'HCT',  'BNP', 
       'BILI',  'INR', 'MED_FOUND', 'ASA_00', 'WARFARIN_00',
       'NOAC_00', 'APT_00', 'BB_00', 'ACE_ARB_00', 'AAD_CLASS_I_00',
       'AAD_CLASS_III_00', 'INSULIN_00', 'METFORMIN_00', 'SGLT2_INHIBITORS_00',
       'DPP4_INHIBTOR_00', 'TZD_00', 'GLP1_00', 'SULFONYLUREA_00']

# %%
data_office = baseline[attris_office]
static_office = pd.concat([data_processed, data_office], axis=1)

# %%
static_office[attris_office].isna().sum()
# Out:
# BP_SYSTOLIC            154
# BP_DIASTOLIC           181
# PULSE                  409
# BMI                    231
# WBC                    261
# HGB                    257
# CR                     209
# EGFR                   222
# K                      214
# NA                     213
# GLUCOSE                243
# ALBUMIN                658
# PLATELETS              260
# HCT                    258
# BNP                    651
# BILI                   705
# INR                    537
# MED_FOUND                0
# ASA_00                   0
# WARFARIN_00              0
# NOAC_00                  0
# APT_00                   0
# BB_00                    0
# ACE_ARB_00               0
# AAD_CLASS_I_00           0
# AAD_CLASS_III_00         0
# INSULIN_00               0
# METFORMIN_00             0
# SGLT2_INHIBITORS_00      0
# DPP4_INHIBTOR_00         0
# TZD_00                   0
# GLP1_00                  0
# SULFONYLUREA_00          0
# dtype: int64

# %% [markdown]
# ## Mean imputation on office measurements except BMI

# %%
office_measures = ['BP_SYSTOLIC','BP_DIASTOLIC', 'PULSE', 'WBC',  'HGB',
       'CR', 'EGFR', 'K',  'NA', 'GLUCOSE','ALBUMIN',
       'PLATELETS',  'HCT',  'BNP', 'BILI',  'INR']

# %%
data_office_filled = static_office.copy()

# %%
for m in office_measures:
    na_df = data_office_filled.loc[data_office_filled[m].isna()]
    # data_filled exclude patients with missing values
    na_rid = na_df.rID
    filtered_rid = [i for i in data_office_filled.rID if i not in na_rid]
    data_filtered = data_office_filled.loc[data_office_filled['rID'].isin(filtered_rid)]
    mean = data_filtered[m].mean()
    data_office_filled.loc[(data_office_filled['rID'].isin(na_rid)),m]=mean

# %% [markdown]
# ## Mean Imputation on BMI

# %% [markdown]
# Use the mean of same gender people to fill the NA values.

# %%
data_filled = data_office_filled.copy()

# %%
bmi_na = data_filled.loc[data_filled['BMI'].isna()]

# %%
bmi_na.FEMALE.value_counts()
# Out:
# 0    130
# 1    101
# Name: FEMALE, dtype: int64

# %%
# data_filled exclude patients with missing BMI
na_rid = bmi_na.rID
filtered_rid = [i for i in data_filled.rID if i not in na_rid]
data_filtered = data_filled.loc[data_filled['rID'].isin(filtered_rid)]

# %%
female_bmi_mean = data_filtered.loc[data_filtered['FEMALE']==1]['BMI'].mean()
male_bmi_mean = data_filtered.loc[data_filtered['FEMALE']==0]['BMI'].mean()

# %%
data_filled.loc[(data_filled['FEMALE']==1) & (data_filled['rID'].isin(na_rid)),'BMI']=female_bmi_mean

data_filled.loc[(data_filled['FEMALE']==0) & (data_filled['rID'].isin(na_rid)),'BMI']=male_bmi_mean

# %%
data_filled.describe()
# Out:
#                 rID  AGE_ADMISSION       FEMALE      HTN_HST  \
# count   2521.000000    2521.000000  2521.000000  2521.000000
# mean    6256.639825       0.748463     0.353828     0.550972
# std     3527.603018       0.194624     0.478251     0.497494
# min        5.000000       0.000000     0.000000     0.000000
# 25%     3200.000000       0.642857     0.000000     0.000000
# 50%     6391.000000       0.785714     0.000000     1.000000
# 75%     9282.000000       0.892857     1.000000     1.000000
# max    12280.000000       1.000000     1.000000     1.000000
#
#        HYPERLIPIDEMIA_HST     DIAB_HST     COPD_HST      CAD_HST      CHF_HST  \
# count         2521.000000  2521.000000  2521.000000  2521.000000  2521.000000
# mean             0.421658     0.391908     0.182071     0.447838     0.669972
# std              0.493922     0.488273     0.385979     0.497370     0.470316
# min              0.000000     0.000000     0.000000     0.000000     0.000000
# ...

# %% [markdown]
# ## Normalize numeric attributes

# %%
attris_numeric2 = ['BMI','WBC',  'HGB',
       'CR', 'EGFR', 'K',  'NA',
        'GLUCOSE','ALBUMIN',
       'PLATELETS',  'HCT',  'BNP', 
       'BILI',  'INR']

# %%
data_filled_norm = data_filled.copy()
for attri in attris_numeric2:
    data_filled_norm[attri] = ((data_filled[attri]-data_filled[attri].min())/
                       (data_filled[attri].max()-data_filled[attri].min()))

# %%
data_filled_norm[attris_numeric2].describe()
# Out:
#                BMI          WBC          HGB           CR         EGFR  \
# count  2521.000000  2521.000000  2521.000000  2521.000000  2521.000000
# mean      0.292009     0.017813     0.331607     0.074078     0.043142
# std       0.126264     0.021734     0.101711     0.069516     0.028344
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.206516     0.012076     0.262626     0.044059     0.029727
# 50%       0.286930     0.016964     0.331648     0.056436     0.043147
# 75%       0.350624     0.020702     0.398990     0.074156     0.053667
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#                  K           NA      GLUCOSE      ALBUMIN    PLATELETS  \
# count  2521.000000  2521.000000  2521.000000  2521.000000  2521.000000
# mean      0.050027     0.664682     0.174290     0.467242     0.254486
# std       0.023505     0.091627     0.097088     0.113575     0.097233
# ...

# %% [markdown]
# # Split to training and validation set

# %%
y = data_filled_norm['readmit_30']

# %%
y = baseline['CTB']

# %%
data_filled_norm.drop('rID', 1, inplace=True)

# %%
data_filled_norm.drop('readmit_30', 1, inplace=True)

# %%
import sklearn.model_selection as model_selection

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(data_filled_norm, y, 
                                        train_size=0.80, test_size=0.20, random_state=1)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegressionCV
from sklearn.metrics import accuracy_score, roc_auc_score

# %%
model_lr = LogisticRegressionCV(15, max_iter=1500)
model_lr.fit(X_train, y_train)
# Out:
# /Users/jinchenxie/miniconda3/envs/research_env/lib/python3.6/site-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# LogisticRegressionCV(Cs=15, class_weight=None, cv='warn', dual=False,
#                      fit_intercept=True, intercept_scaling=1.0, l1_ratios=None,
#                      max_iter=1500, multi_class='warn', n_jobs=None,
#                      penalty='l2', random_state=None, refit=True, scoring=None,
#                      solver='lbfgs', tol=0.0001, verbose=0)

# %%
LR_predicted = model_lr.predict(X_test)
LR_accuracy = accuracy_score(y_test, LR_predicted)
LR_auc = roc_auc_score(y_test, LR_predicted)

# %%
LR_accuracy
# Out:
# 0.6217821782178218

# %%
LR_auc
# Out:
# 0.6238223101563971

# %%
y_test.value_counts()/len(y_test)
# Out:
# 1    0.516832
# 0    0.483168
# Name: CTB, dtype: float64

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_rf = RandomForestClassifier(n_estimators = 50, random_state = 0, max_depth=30)

# %%
model_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=30, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=50,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %%
RF_predicted = model_rf.predict(X_test)
RF_accuracy = accuracy_score(y_test, RF_predicted)
RF_auc = roc_auc_score(y_test, RF_predicted)

# %%
RF_accuracy
# Out:
# 0.6376237623762376

# %%
RF_auc
# Out:
# 0.6399488097481314

# %% [markdown]
# # Examine the Office Visit Measurements

# %% [markdown]
# 1. Examine the 'DAYS_TO_CLOSEST_OFFICE_VISIT' attribute

# %%
baseline[['rID','DAYS_TO_CLOSEST_OFFICE_VISIT']]
# Out:
#         rID  DAYS_TO_CLOSEST_OFFICE_VISIT
# 0         5                           -63
# 1        10                            -3
# 2        16                             0
# 3        28                             6
# 4        31                             8
# ...     ...                           ...
# 2516  12247                            -2
# 2517  12253                             7
# 2518  12260                            51
# 2519  12263                            61
# 2520  12280                            24
#
# [2521 rows x 2 columns]

# %%
office_time_df = baseline.loc[(baseline['DAYS_TO_CLOSEST_OFFICE_VISIT']>50) | 
                             (baseline['DAYS_TO_CLOSEST_OFFICE_VISIT']<-50)]

# %%
office_time_df[['rID', 'DAYS_TO_CLOSEST_OFFICE_VISIT']]
# Out:
#         rID  DAYS_TO_CLOSEST_OFFICE_VISIT
# 0         5                           -63
# 6        40                            89
# 15      103                            52
# 19      120                            81
# 22      148                            59
# 32      175                           -77
# 33      178                            90
# 35      194                            61
# 36      195                            58
# 41      211                            76
# 43      221                            89
# 53      265                            75
# 69      376                            77
# 93      471                            65
# 118     574                           -54
# 128     624                            53
# 132     642                            55
# 136     665                            69
# 146     709                            66
# 158     774                           -89
# 161     788                           -68
# ...

# %%
office_rID = office_time_df.rID
readmit_time_df = admission.loc[admission['rID'].isin(office_rID)]
readmit_time_df[['rID', 'LOS_DAYS','READMISSION_DAYS']][:100]
# Out:
#      rID  LOS_DAYS  READMISSION_DAYS
# 0      5     3.121               NaN
# 1      5     2.394            58.847
# 2      5     2.194           600.973
# 3      5     0.892           697.292
# 18    40    17.316               NaN
# 19    40     2.955             7.942
# 20    40     1.376           119.382
# 53   103     3.097               NaN
# 54   103     8.142            29.909
# 55   103     5.332            57.691
# 56   103     5.078           268.966
# 57   103     5.808           281.223
# 58   103     3.877           374.318
# 59   103     7.111           387.977
# 60   103     7.864           440.123
# 61   103    13.031           464.032
# 62   103     6.917           534.335
# 90   120     3.927               NaN
# 91   120     4.781            24.299
# 92   120     9.832            39.067
# 93   120    33.253            93.773
# 107  148    38.281               NaN
# 108  148     6.702             3.264
# 109  148     2.472            21.278
# ...

# %% [markdown]
# # Examine the initial admission measurements

# %%
baseline_old.loc[baseline_old['total_adms']>1].shape
# Out:
# (2083, 290)

# %%
baseline_old.loc[baseline_old['total_adms']==1].shape
# Out:
# (438, 290)

# %%
baseline_old.shape
# Out:
# (2521, 290)

# %%
baseline.shape
# Out:
# (2521, 143)

# %% [markdown]
# # Examine the HIS

# %%
his_df = baseline[attris_his]

# %%
his_df.sum()
# Out:
# HTN_HST                        1389
# HYPERLIPIDEMIA_HST             1063
# DIAB_HST                        988
# COPD_HST                        459
# CAD_HST                        1129
# CHF_HST                        1689
# AFIB_HST                        676
# PH_HST                           58
# PE_HST                           92
# CARDIAC_ARREST_HST               24
# VTVF_HST                        350
# VASCULARDISEASE_HST             271
# DVT_HST                          66
# STROKE_HST                      203
# HEMO_STROKE_HST                  19
# MAJOR_BLEED_HST                 226
# CKD_HST                         283
# ESRD_HST                         89
# CIRRHOSIS_HST                    36
# HX_SEPTIC_SHOCK                   1
# HX_SEPSIS                        19
# HX_CAROTID_OCCLUSION             88
# RESTRICTIVE_CARDIOMYOPATHY        1
# HYPERTROPHIC_CARDIOMYOPATHY       8
# ISCHEMIC_CARDIOMYOPATHY         187
# PERIPARTUM_CARDIOMYOPATHY         7
# ...

# %%
admission['PATIENT_TYPE_DESCRIPTION'].value_counts()
# Out:
# I  INPATIENT        12114
# S  SAME DAY SERV      389
# EMERGENCY DEPT         20
# DO DIRECT OBS           2
# Name: PATIENT_TYPE_DESCRIPTION, dtype: int64

# %%
admission['IPOP'].value_counts()
# Out:
# IP        12114
# OBS         332
# OUTPAT       76
# EDTRAN        2
# EDTR          1
# Name: IPOP, dtype: int64

# %%
baseline.columns[:100]
# Out:
# Index(['rID', 'LOS_DAYS', 'HOSP_CR', 'HOSP_BILI', 'HOSP_INR', 'HOSP_NA',
#        'HOSP_EGFR', 'PRIMARY_DIAGNOSIS_CODE', 'PRIMARY_DIAGNOSIS_DESCRIPTION',
#        'AGE_ADMISSION', 'FEMALE', 'RACE', 'BMI',
#        'DAYS_TO_CLOSEST_OFFICE_VISIT', 'DEPARTMENT_SPECIALTY', 'BP_SYSTOLIC',
#        'BP_DIASTOLIC', 'PULSE', 'FINANCIAL_CLASS_CODE', 'FINANCIAL_CLASS',
#        'HOSP_ROLLUP_GROUPING1', 'HOSP_ROLLUP_GROUPING2', 'DC_MILRINONE',
#        'DC_DOBUTAMINE', 'DC_DOPAMINE', 'LVEF', 'CLOSEST_LVEF_DAYS', 'RV_FUNC',
#        'CLOSEST_RV_FUNC_DAYS', 'AR', 'CLOSEST_AR_DAYS', 'MR',
#        'CLOSEST_MR_DAYS', 'PR', 'CLOSEST_PR_DAYS', 'TR', 'CLOSEST_TR_DAYS',
#        'PRE_CRT', 'PRIOR_STERNOTOMY', 'PRIOR_PCI', 'PRIOR_CABG', 'PRIOR_TAVR',
#        'PRIOR_SAVR_MECH', 'PRIOR_SAVR_BIO', 'PRIOR_SURG_AO_GRFT',
#        'PRIOR_ENDO_AO_GRFT', 'PRIOR_AO_VLV_REPAIR', 'PRIOR_SMVR', 'PRIOR_SPVR',
#        'PRIOR_STVR', 'HTN_HST', 'HYPERLIPIDEMIA_HST', 'DIAB_HST', 'COPD_HST',
# ...

# %%
baseline.columns[100:]
# Out:
# Index(['APT_00', 'BB_00', 'ACE_ARB_00', 'AAD_CLASS_I_00', 'AAD_CLASS_III_00',
#        'INSULIN_00', 'METFORMIN_00', 'SGLT2_INHIBITORS_00', 'DPP4_INHIBTOR_00',
#        'TZD_00', 'GLP1_00', 'SULFONYLUREA_00', 'WBC', 'WBC_DAYS', 'HGB',
#        'HGB_DAYS', 'CR', 'CR_DAYS', 'EGFR', 'EGFR_DAYS', 'K', 'K_DAYS', 'NA',
#        'NA_DAYS', 'GLUCOSE', 'GLUCOSE_DAYS', 'ALBUMIN', 'ALBUMIN_DAYS',
#        'PLATELETS', 'PLATELETS_DAYS', 'HCT', 'HCT_DAYS', 'BNP', 'BNP_DAYS',
#        'BILI', 'BILI_DAYS', 'INR', 'INR_DAYS', 'VERIFIED_MELD', 'RHC_FOUND',
#        'CTB', 'FOLLOWUP_DAYS', 'readmit_30'],
#       dtype='object')

# %%
baseline['HF_ETIOLOGY_LABEL']
# Out:
# 0         OTHER
# 1         OTHER
# 2         OTHER
# 3          NONE
# 4          NONE
#          ...
# 2516       NONE
# 2517      OTHER
# 2518      OTHER
# 2519    ISCHEMI
# 2520       NONE
# Name: HF_ETIOLOGY_LABEL, Length: 2521, dtype: object

# %%
admission_old[['rID','PRIMARY_DIAGNOSIS_CODE','PRIMARY_DIAGNOSIS_CODE_TYPE','PRIMARY_DIAGNOSIS_DESCRIPTION']]
# Out:
#          rID PRIMARY_DIAGNOSIS_CODE  PRIMARY_DIAGNOSIS_CODE_TYPE  \
# 0          5                 I50.23                           10
# 1          5                  J44.1                           10
# 2          5                  J44.1                           10
# 3          5                  I11.0                           10
# 4         10                 I50.43                           10
# ...      ...                    ...                          ...
# 12520  12280                 I50.23                           10
# 12521  12280               T80.211A                           10
# 12522  12280                  I13.0                           10
# 12523  12280                  J44.1                           10
# 12524  12280                 I50.23                           10
#
#                            PRIMARY_DIAGNOSIS_DESCRIPTION
# 0      ACUTE ON CHRONIC SYSTOLIC (CONGESTIVE) HEART F...
# 1      CHRONIC OBSTRUCTIVE PULMONARY DISEASE W (ACUTE...
# ...

# %%
admission_old['PRIMARY_DIAGNOSIS_DESCRIPTION'].value_counts()
# Out:
# AC-CHR SYSTOL HRT FAIL                                         971
# CONGESTVE HRT FAILUR NOS                                       925
# HYP HRT & CHR KDNY DIS W HRT FAIL AND STG 1-4/UNSP CHR KDNY    675
# ACUTE ON CHRONIC SYSTOLIC (CONGESTIVE) HEART FAILURE           518
# AC-CHR COMB S/D HRT FAIL                                       459
#                                                               ...
# SUBARACHNOID HEMORRHAGE                                          1
# CRAMP AND SPASM                                                  1
# STAPH SEPTICEMIA NEC                                             1
# OTHER SPECIFIED DISORDERS OF BRAIN                               1
# IDIOPATHIC GOUT, LEFT KNEE                                       1
# Name: PRIMARY_DIAGNOSIS_DESCRIPTION, Length: 1478, dtype: int64
